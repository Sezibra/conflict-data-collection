# %%
from google.cloud import bigquery
import os

os.chdir('/Users/cansezgin/Library/Mobile Documents/com~apple~CloudDocs/Claude_Projects/Computational Social Sciences/conflict-data-collection')
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'credentials/bigquery-key.json'

client = bigquery.Client()

query = """
SELECT COUNT(*) as total 
FROM `gdelt-bq.gdeltv2.events` 
WHERE ActionGeo_CountryCode = 'ET' 
AND CAST(SQLDATE AS STRING) BETWEEN '20201101' AND '20201130'
"""

result = client.query(query).to_dataframe()
print(result)
# Out:
# /opt/anaconda3/envs/conflict-text/lib/python3.11/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#    total
# 0  28967
